# %% [markdown]
# # Authors first and last commit date
#
# This notebooks focus on retrieving data from ES and using Pandas to perform some basic analysis on it.

# %% [markdown]
# ## Import libraries
#
# First we need to import those Python modules we are going to use. We could import them at any point before using them.

# %%
import certifi
import configparser
import json
import os
import sys

from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search

# %% [markdown]
# ## Declaring functions
# We can define new functions at any point. In this case we decided to declare 'create_conn' function here at the begining because is a generic function. In fact we could create a separate module with this kind of general functions and import that module in every notebook we need to create an ES connection.
#
# Notice we are pointing to '../.settings' file to use same config as in plain script version of this code.

# %%
def create_conn():
    """Creates an ES connection from ''.settings' file.

    ''.settings' contents sample:
    [ElasticSearch]

    user=john_smith
    password=aDifficultOne
    host=my.es.host
    port=80
    path=es_path_if_any
    """

    parser = configparser.ConfigParser()
    parser.read('../.settings')

    section = parser['ElasticSearch']
    user = section['user']
    password = section['password']
    host = section['host']
    port = section['port']
    path = section['path']

    connection = "https://" + user + ":" + password + "@" + host + ":" + port \
                + "/" + path

    es_read = Elasticsearch([connection], use_ssl=True,
                            verity_certs=True, ca_cert=certifi.where(),
                            scroll='300m', timeout=1000)

    return es_read

# %% [markdown]
# ## Querying ES
# Following code creates an ES connection and executes the query to get, for each author, first and last commit dates.
#
# In order to get unique authors, a bucket is created using 'author_uuid' field.
#
# Notice that a filter is applied to get data for whole years. Thus, we exclude data for current year.

# %%
"""Query ES to get first and last commit of each author together with
some extra info like .
"""
es_conn = create_conn()

# Create search object
s = Search(using=es_conn, index='git')

# FILTER: retrieve commits before given year
s = s.filter('range', grimoire_creation_date={'lt': 'now/y'})

# Bucketize by uuid and get first and last commit (commit date is stored in
# author_date field)
s.aggs.bucket('authors', 'terms', field='author_uuid', size=10000000) \
    .metric('first', 'top_hits',
            _source=['author_date', 'author_org_name', 'author_uuid', 'project'],
            size=1,
            sort=[{"author_date": {"order": "asc"}}]) \
    .metric('last_commit', 'max', field='author_date')

# Sort by commit date
s = s.sort("author_date")

result = s.execute()

# %% [markdown]
# # Print results
#
# From here, we can start playing with the data, but first we can print those results to have a look at them.
#
# Notice we can use variables from other cells that were executed previosly (look at numbers between square brackets if not sure about execution order).

# %%
from pprint import pprint

result_buckets = result.to_dict()['aggregations']['authors']['buckets']

pprint(result_buckets)
# Out:
# [{'doc_count': 29838,
#   'first': {'hits': {'hits': [{'_id': '40a74d03976c4810bf4b5c57b94c9b79c9b6b087',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-05-19T07:41:30',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '57de6040b8a98143a5eb938109e4b0a907038d77',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1337413290000]}],
#                      'max_score': None,
#                      'total': 29838}},
#   'key': '57de6040b8a98143a5eb938109e4b0a907038d77',
#   'last_commit': {'value': 1514475862000.0,
#                   'value_as_string': '2017-12-28T15:44:22.000Z'}},
#  {'doc_count': 21749,
#   'first': {'hits': {'hits': [{'_id': '86ffac32683d0b3c2234da65c9f43b44e84c4742',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2013-04-25T12:37:57',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '08d592c867d7072e0369a3c621305de726ebffad',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1366893477000]}],
#                      'max_score': None,
#                      'total': 21749}},
#   'key': '08d592c867d7072e0369a3c621305de726ebffad',
#   'last_commit': {'value': 1512403306000.0,
#                   'value_as_string': '2017-12-04T16:01:46.000Z'}},
#  {'doc_count': 4755,
#   'first': {'hits': {'hits': [{'_id': '79327d01aed30bf5b3ec44875acb7f58e25197a1',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2013-05-27T16:33:40',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '3eb49803019beb6bc40c54414fa505da8c5bc355',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1369672420000]}],
#                      'max_score': None,
#                      'total': 4755}},
#   'key': '3eb49803019beb6bc40c54414fa505da8c5bc355',
#   'last_commit': {'value': 1509189942000.0,
#                   'value_as_string': '2017-10-28T11:25:42.000Z'}},
#  {'doc_count': 2998,
#   'first': {'hits': {'hits': [{'_id': '0226986ac0cc98844252ba2e81214ab1aefd2929',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-09-04T10:54:04',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '3999a9c86b4fa99ed2248b342428458a2df5c3f7',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1346756044000]}],
#                      'max_score': None,
#                      'total': 2998}},
#   'key': '3999a9c86b4fa99ed2248b342428458a2df5c3f7',
#   'last_commit': {'value': 1513966378000.0,
#                   'value_as_string': '2017-12-22T18:12:58.000Z'}},
#  {'doc_count': 2276,
#   'first': {'hits': {'hits': [{'_id': 'c1036190e2a453caa9fc9814411a6dd697abc547',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2013-10-22T20:29:24',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '75fc28ef4643de5323e89fb26e4e67c97b24f507',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1382473764000]}],
#                      'max_score': None,
#                      'total': 2276}},
#   'key': '75fc28ef4643de5323e89fb26e4e67c97b24f507',
#   'last_commit': {'value': 1514554816000.0,
#                   'value_as_string': '2017-12-29T13:40:16.000Z'}},
#  {'doc_count': 1223,
#   'first': {'hits': {'hits': [{'_id': '1583d2fa1bb1d3000f09624dd784cc6a26f9535b',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2009-11-05T15:37:23',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '858fcf6c665e844966734fcfd9da28b1bddf895a',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1257435443000]}],
#                      'max_score': None,
#                      'total': 1223}},
#   'key': '858fcf6c665e844966734fcfd9da28b1bddf895a',
#   'last_commit': {'value': 1343840326000.0,
#                   'value_as_string': '2012-08-01T16:58:46.000Z'}},
#  {'doc_count': 943,
#   'first': {'hits': {'hits': [{'_id': '95f41bf099dbf43265eb87a499d186725ca23153',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2010-02-01T17:17:52',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': 'd3fb2dae1d7dc11c8f5a8ddaf019f36e650e044b',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1265044672000]}],
#                      'max_score': None,
#                      'total': 943}},
#   'key': 'd3fb2dae1d7dc11c8f5a8ddaf019f36e650e044b',
#   'last_commit': {'value': 1345228755000.0,
#                   'value_as_string': '2012-08-17T18:39:15.000Z'}},
#  {'doc_count': 608,
#   'first': {'hits': {'hits': [{'_id': '0efe3857e9137a06748360f6fda8b8f19c4d0a48',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2014-02-21T15:10:55',
#                                            'author_org_name': 'Universidad Rey '
#                                                               'Juan Carlos',
#                                            'author_uuid': '0721454571b47c7b5d40ffa107f5245353a4ff66',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1392995455000]}],
#                      'max_score': None,
#                      'total': 608}},
#   'key': '0721454571b47c7b5d40ffa107f5245353a4ff66',
#   'last_commit': {'value': 1514738414000.0,
#                   'value_as_string': '2017-12-31T16:40:14.000Z'}},
#  {'doc_count': 475,
#   'first': {'hits': {'hits': [{'_id': '148fcc427fa3cc1e5cd8fa352eae557e6dc99ffb',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2009-11-05T10:50:13',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '54f3d0fa3116f1b3a3019bdccf563bdbdbfab2c6',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1257418213000]}],
#                      'max_score': None,
#                      'total': 475}},
#   'key': '54f3d0fa3116f1b3a3019bdccf563bdbdbfab2c6',
#   'last_commit': {'value': 1309274891000.0,
#                   'value_as_string': '2011-06-28T15:28:11.000Z'}},
#  {'doc_count': 445,
#   'first': {'hits': {'hits': [{'_id': '48427e778b173567a657c8cbc96523abaec91b01',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2014-11-18T16:37:52',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '2f7739242d958fa5c683974587c1f913f6add0cd',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1416328672000]}],
#                      'max_score': None,
#                      'total': 445}},
#   'key': '2f7739242d958fa5c683974587c1f913f6add0cd',
#   'last_commit': {'value': 1512470115000.0,
#                   'value_as_string': '2017-12-05T10:35:15.000Z'}},
#  {'doc_count': 416,
#   'first': {'hits': {'hits': [{'_id': '947bf97adfa77a4e25fc0bc24c59e4e2f7cabb06',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2015-07-14T11:52:59',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '0cac4ef12631d5b0ef2fa27ef09729b45d7a68c1',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1436874779000]}],
#                      'max_score': None,
#                      'total': 416}},
#   'key': '0cac4ef12631d5b0ef2fa27ef09729b45d7a68c1',
#   'last_commit': {'value': 1511786368000.0,
#                   'value_as_string': '2017-11-27T12:39:28.000Z'}},
#  {'doc_count': 416,
#   'first': {'hits': {'hits': [{'_id': '0b4835ae2ee14d07ebd65500e9d6f213fbe5aeaa',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2011-01-21T19:43:44',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': 'a18a6a31965a46c24113018b752a49eae74fee13',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1295639024000]}],
#                      'max_score': None,
#                      'total': 416}},
#   'key': 'a18a6a31965a46c24113018b752a49eae74fee13',
#   'last_commit': {'value': 1349296611000.0,
#                   'value_as_string': '2012-10-03T20:36:51.000Z'}},
#  {'doc_count': 371,
#   'first': {'hits': {'hits': [{'_id': '712020b873c93e43a324b25aea4079bdab5adcbc',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2010-09-10T22:26:41',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '3f7832ea49c7e3174f907ec58200ad3c765b7b71',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1284157601000]}],
#                      'max_score': None,
#                      'total': 371}},
#   'key': '3f7832ea49c7e3174f907ec58200ad3c765b7b71',
#   'last_commit': {'value': 1302274187000.0,
#                   'value_as_string': '2011-04-08T14:49:47.000Z'}},
#  {'doc_count': 268,
#   'first': {'hits': {'hits': [{'_id': '73ebef873a47fb096412c8e009705617e9fe42f6',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2011-04-26T08:45:01',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '0d1a97da22adbd366a57c174e3106ebdef981ee3',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1303807501000]}],
#                      'max_score': None,
#                      'total': 268}},
#   'key': '0d1a97da22adbd366a57c174e3106ebdef981ee3',
#   'last_commit': {'value': 1345228228000.0,
#                   'value_as_string': '2012-08-17T18:30:28.000Z'}},
#  {'doc_count': 245,
#   'first': {'hits': {'hits': [{'_id': '4a493ae013455176ca1f4546dfab116295bf7b5d',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2014-11-19T00:20:32',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '0e7ec921b50e2d19bba61857d12bdc26a2db5867',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1416356432000]}],
#                      'max_score': None,
#                      'total': 245}},
#   'key': '0e7ec921b50e2d19bba61857d12bdc26a2db5867',
#   'last_commit': {'value': 1464633800000.0,
#                   'value_as_string': '2016-05-30T18:43:20.000Z'}},
#  {'doc_count': 196,
#   'first': {'hits': {'hits': [{'_id': 'da1ce85669e142d1c9edd5b8a0698e5e1ef66ad2',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2009-10-14T15:23:08',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '311d49a75694e820005b26286ee39d6afc8c1b70',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1255533788000]}],
#                      'max_score': None,
#                      'total': 196}},
#   'key': '311d49a75694e820005b26286ee39d6afc8c1b70',
#   'last_commit': {'value': 1277218027000.0,
#                   'value_as_string': '2010-06-22T14:47:07.000Z'}},
#  {'doc_count': 195,
#   'first': {'hits': {'hits': [{'_id': '52d5b5397f8915365437aeb26335723e2b433f6e',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2016-11-17T16:59:44',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '71865329622c972b856abae58ad4095cd2086fa2',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1479401984000]}],
#                      'max_score': None,
#                      'total': 195}},
#   'key': '71865329622c972b856abae58ad4095cd2086fa2',
#   'last_commit': {'value': 1513961049000.0,
#                   'value_as_string': '2017-12-22T16:44:09.000Z'}},
#  {'doc_count': 160,
#   'first': {'hits': {'hits': [{'_id': '5ea1f146a9294fc6b25b339ebfeef88378edec08',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-01-28T00:48:28',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '637fa327b9edbc6181dc4ce79618e97e796df511',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1327711708000]}],
#                      'max_score': None,
#                      'total': 160}},
#   'key': '637fa327b9edbc6181dc4ce79618e97e796df511',
#   'last_commit': {'value': 1349290887000.0,
#                   'value_as_string': '2012-10-03T19:01:27.000Z'}},
#  {'doc_count': 113,
#   'first': {'hits': {'hits': [{'_id': '03640cd324255058fe06437bcce2e0a0c9c175d9',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-09-07T14:46:30',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '3af32d529fce2e7dc632bb26fea5ed4abcb3fcd6',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1504795590000]}],
#                      'max_score': None,
#                      'total': 113}},
#   'key': '3af32d529fce2e7dc632bb26fea5ed4abcb3fcd6',
#   'last_commit': {'value': 1513339017000.0,
#                   'value_as_string': '2017-12-15T11:56:57.000Z'}},
#  {'doc_count': 113,
#   'first': {'hits': {'hits': [{'_id': 'efb01fd2d85737fae459cec9e319e0ad0a2c1389',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2014-10-24T11:13:11',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': 'a7c4988a7b78559f40ac99131a9329c33ac2ce70',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1414149191000]}],
#                      'max_score': None,
#                      'total': 113}},
#   'key': 'a7c4988a7b78559f40ac99131a9329c33ac2ce70',
#   'last_commit': {'value': 1508089813000.0,
#                   'value_as_string': '2017-10-15T17:50:13.000Z'}},
#  {'doc_count': 105,
#   'first': {'hits': {'hits': [{'_id': '1d247c8c931a7070d5b5ad0e0e69d2b9c3c7ba91',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2016-01-20T19:04:30',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': 'cc1000a28d57ed5351bb8a62dfff5e37569b2df8',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1453316670000]}],
#                      'max_score': None,
#                      'total': 105}},
#   'key': 'cc1000a28d57ed5351bb8a62dfff5e37569b2df8',
#   'last_commit': {'value': 1512154883000.0,
#                   'value_as_string': '2017-12-01T19:01:23.000Z'}},
#  {'doc_count': 94,
#   'first': {'hits': {'hits': [{'_id': '93372991dfbebd06f23a56895975d9efcc273efd',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-05-24T12:10:26',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '16cd95315b0b28ee70e1f73447a64d5e2b964eb5',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1337861426000]}],
#                      'max_score': None,
#                      'total': 94}},
#   'key': '16cd95315b0b28ee70e1f73447a64d5e2b964eb5',
#   'last_commit': {'value': 1348594901000.0,
#                   'value_as_string': '2012-09-25T17:41:41.000Z'}},
#  {'doc_count': 80,
#   'first': {'hits': {'hits': [{'_id': '096850764c2c0a3a833cedb4e28c23364f91c45e',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-03-12T12:50:31',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '27d96590fb2ca5dedd4507bda1d792f295223274',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1331556631000]}],
#                      'max_score': None,
#                      'total': 80}},
#   'key': '27d96590fb2ca5dedd4507bda1d792f295223274',
#   'last_commit': {'value': 1340368388000.0,
#                   'value_as_string': '2012-06-22T12:33:08.000Z'}},
#  {'doc_count': 66,
#   'first': {'hits': {'hits': [{'_id': '3d5ee1163123ae6666c41b97d8ff8e748c00d5c0',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2009-11-05T10:48:13',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '0a7e39e91aa13ce4b9bfba8717308339e16377d9',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1257418093000]}],
#                      'max_score': None,
#                      'total': 66}},
#   'key': '0a7e39e91aa13ce4b9bfba8717308339e16377d9',
#   'last_commit': {'value': 1286817431000.0,
#                   'value_as_string': '2010-10-11T17:17:11.000Z'}},
#  {'doc_count': 55,
#   'first': {'hits': {'hits': [{'_id': '7879ff09e5296847fd038a92759733e9a924d2cb',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2011-01-25T15:47:03',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': 'b83582fafb021a9b640b2dfb0404abced7b39661',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1295970423000]}],
#                      'max_score': None,
#                      'total': 55}},
#   'key': 'b83582fafb021a9b640b2dfb0404abced7b39661',
#   'last_commit': {'value': 1327500024000.0,
#                   'value_as_string': '2012-01-25T14:00:24.000Z'}},
#  {'doc_count': 45,
#   'first': {'hits': {'hits': [{'_id': '5a6a9944a432bac8d8784329a9c396f6ef613578',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-06-29T04:25:21',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '0d4ba0fcf67b5f664e994d44ef204752c37e39db',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1340943921000]}],
#                      'max_score': None,
#                      'total': 45}},
#   'key': '0d4ba0fcf67b5f664e994d44ef204752c37e39db',
#   'last_commit': {'value': 1348761115000.0,
#                   'value_as_string': '2012-09-27T15:51:55.000Z'}},
#  {'doc_count': 42,
#   'first': {'hits': {'hits': [{'_id': 'e53e773ee7cb583caf007f23bc630c56809f9f01',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2010-04-05T15:17:46',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '8335333ea8bc65ddcffb768919a02b80eff3e640',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1270480666000]}],
#                      'max_score': None,
#                      'total': 42}},
#   'key': '8335333ea8bc65ddcffb768919a02b80eff3e640',
#   'last_commit': {'value': 1275495707000.0,
#                   'value_as_string': '2010-06-02T16:21:47.000Z'}},
#  {'doc_count': 39,
#   'first': {'hits': {'hits': [{'_id': 'df73d25ac03b872c439267671021de5adb20a3da',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2015-07-15T10:21:51',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '637ec46ef4bc4b36f4820a57bfd6862b5f9cba2e',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1436955711000]}],
#                      'max_score': None,
#                      'total': 39}},
#   'key': '637ec46ef4bc4b36f4820a57bfd6862b5f9cba2e',
#   'last_commit': {'value': 1462536323000.0,
#                   'value_as_string': '2016-05-06T12:05:23.000Z'}},
#  {'doc_count': 38,
#   'first': {'hits': {'hits': [{'_id': '8f0a17dfe3db8f5d0beb9f14798af1144f2a5534',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2014-03-10T10:24:33',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '38070f4707f1757bf26e6de24330deac7da4485a',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1394447073000]}],
#                      'max_score': None,
#                      'total': 38}},
#   'key': '38070f4707f1757bf26e6de24330deac7da4485a',
#   'last_commit': {'value': 1489600111000.0,
#                   'value_as_string': '2017-03-15T17:48:31.000Z'}},
#  {'doc_count': 36,
#   'first': {'hits': {'hits': [{'_id': '7e4f9cc20f6e64a9f362510fbc1a3e57272432c6',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2015-10-11T19:08:22',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '059dcccf4a3c177ff6e496bccaf4da6160732ced',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1444590502000]}],
#                      'max_score': None,
#                      'total': 36}},
#   'key': '059dcccf4a3c177ff6e496bccaf4da6160732ced',
#   'last_commit': {'value': 1452026666000.0,
#                   'value_as_string': '2016-01-05T20:44:26.000Z'}},
#  {'doc_count': 35,
#   'first': {'hits': {'hits': [{'_id': '6a3a26b75e1436e5ab3d49cf45ea089f81257469',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2010-04-10T10:48:32',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '35a9d29ad910a5d75c660299a477da7d61497af3',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1270896512000]}],
#                      'max_score': None,
#                      'total': 35}},
#   'key': '35a9d29ad910a5d75c660299a477da7d61497af3',
#   'last_commit': {'value': 1272484395000.0,
#                   'value_as_string': '2010-04-28T19:53:15.000Z'}},
#  {'doc_count': 27,
#   'first': {'hits': {'hits': [{'_id': 'd82fb5a2f0fc34b4a3d6e451a1060ddd9779113d',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-07-30T22:32:42',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '573867498e2ff89100afa6bb22f70b862e96964a',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1343687562000]}],
#                      'max_score': None,
#                      'total': 27}},
#   'key': '573867498e2ff89100afa6bb22f70b862e96964a',
#   'last_commit': {'value': 1344135275000.0,
#                   'value_as_string': '2012-08-05T02:54:35.000Z'}},
#  {'doc_count': 26,
#   'first': {'hits': {'hits': [{'_id': 'affb957017e033087cb40775651acb6ed44c527d',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2014-05-26T00:23:42',
#                                            'author_org_name': 'Eclipse '
#                                                               'Foundation',
#                                            'author_uuid': 'abe3d01a04565d2a645ad372da92435506a37438',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1401063822000]}],
#                      'max_score': None,
#                      'total': 26}},
#   'key': 'abe3d01a04565d2a645ad372da92435506a37438',
#   'last_commit': {'value': 1401166273000.0,
#                   'value_as_string': '2014-05-27T04:51:13.000Z'}},
#  {'doc_count': 25,
#   'first': {'hits': {'hits': [{'_id': '9292dbee7aaed38607c24d6d1fb5638c3b37137e',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2013-12-23T11:00:16',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '6accd7f51d2bedfc2144204f533d03a83ea68313',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1387796416000]}],
#                      'max_score': None,
#                      'total': 25}},
#   'key': '6accd7f51d2bedfc2144204f533d03a83ea68313',
#   'last_commit': {'value': 1387796416000.0,
#                   'value_as_string': '2013-12-23T11:00:16.000Z'}},
#  {'doc_count': 21,
#   'first': {'hits': {'hits': [{'_id': '3b9acd83340d34ad48f36abcaa061791f3b27ff2',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2016-07-28T16:12:03',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '08eab6ef3ea49e880bba3a1a7ae8030c2d0b1297',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1469722323000]}],
#                      'max_score': None,
#                      'total': 21}},
#   'key': '08eab6ef3ea49e880bba3a1a7ae8030c2d0b1297',
#   'last_commit': {'value': 1509992926000.0,
#                   'value_as_string': '2017-11-06T18:28:46.000Z'}},
#  {'doc_count': 19,
#   'first': {'hits': {'hits': [{'_id': '0cac2acfbeec7f2dbfdae67d3a958eea58dc7c86',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2011-04-27T16:34:14',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '8034601bb611d8467e91bac7ce56c332790729bd',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1303922054000]}],
#                      'max_score': None,
#                      'total': 19}},
#   'key': '8034601bb611d8467e91bac7ce56c332790729bd',
#   'last_commit': {'value': 1319301563000.0,
#                   'value_as_string': '2011-10-22T16:39:23.000Z'}},
#  {'doc_count': 17,
#   'first': {'hits': {'hits': [{'_id': '981d5969c89c5e6afcb27ef88c271b8dfacf60ae',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-02-10T22:41:29',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '05a59bcab4ea18cde6a069bc27d06657254bcb4f',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1328913689000]}],
#                      'max_score': None,
#                      'total': 17}},
#   'key': '05a59bcab4ea18cde6a069bc27d06657254bcb4f',
#   'last_commit': {'value': 1341850954000.0,
#                   'value_as_string': '2012-07-09T16:22:34.000Z'}},
#  {'doc_count': 17,
#   'first': {'hits': {'hits': [{'_id': '1e20a4505c10a551dbd70884ecd3ea5f2fff0d4a',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2011-02-11T19:17:18',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '61eeffb994404fb5dd5e20445eb33d731b3e1d29',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1297451838000]}],
#                      'max_score': None,
#                      'total': 17}},
#   'key': '61eeffb994404fb5dd5e20445eb33d731b3e1d29',
#   'last_commit': {'value': 1345731893000.0,
#                   'value_as_string': '2012-08-23T14:24:53.000Z'}},
#  {'doc_count': 16,
#   'first': {'hits': {'hits': [{'_id': '052731b3b56e24b545c228bd080490f1806d50a6',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2009-11-11T14:36:42',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '1824e55b84e35e19d8cdd414932a54123863cc85',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1257950202000]}],
#                      'max_score': None,
#                      'total': 16}},
#   'key': '1824e55b84e35e19d8cdd414932a54123863cc85',
#   'last_commit': {'value': 1309436806000.0,
#                   'value_as_string': '2011-06-30T12:26:46.000Z'}},
#  {'doc_count': 16,
#   'first': {'hits': {'hits': [{'_id': '2fa5812104714f8c6524e9d56fff29ad4234b2b9',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2010-01-15T11:17:05',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '44725024cabcedb8ec90741eb99661613bfba2e9',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1263554225000]}],
#                      'max_score': None,
#                      'total': 16}},
#   'key': '44725024cabcedb8ec90741eb99661613bfba2e9',
#   'last_commit': {'value': 1273764319000.0,
#                   'value_as_string': '2010-05-13T15:25:19.000Z'}},
#  {'doc_count': 11,
#   'first': {'hits': {'hits': [{'_id': '26f368644da47174bbcf8d5cd10a1c8078dea0bf',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2013-10-26T10:20:58',
#                                            'author_org_name': 'Wikimedia '
#                                                               'Foundation',
#                                            'author_uuid': '30548cf5f2cce8d5928c8447e547bac789ddcb08',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1382782858000]}],
#                      'max_score': None,
#                      'total': 11}},
#   'key': '30548cf5f2cce8d5928c8447e547bac789ddcb08',
#   'last_commit': {'value': 1440513580000.0,
#                   'value_as_string': '2015-08-25T14:39:40.000Z'}},
#  {'doc_count': 10,
#   'first': {'hits': {'hits': [{'_id': 'd8e7005b0c791fc79ee8aa75ff32934c12c864bf',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2010-01-25T14:08:26',
#                                            'author_org_name': 'Geeknet, Inc.',
#                                            'author_uuid': '2be2aadaf1dd3ca7a6a4409846bc0fa33a57a124',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1264428506000]}],
#                      'max_score': None,
#                      'total': 10}},
#   'key': '2be2aadaf1dd3ca7a6a4409846bc0fa33a57a124',
#   'last_commit': {'value': 1266838395000.0,
#                   'value_as_string': '2010-02-22T11:33:15.000Z'}},
#  {'doc_count': 8,
#   'first': {'hits': {'hits': [{'_id': '918c29c9758e6d8ec1398b418d73c81ea692426c',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2016-07-07T11:53:40',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '4fcec5a968246d8342e4acfceb9174531c8545c1',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1467892420000]}],
#                      'max_score': None,
#                      'total': 8}},
#   'key': '4fcec5a968246d8342e4acfceb9174531c8545c1',
#   'last_commit': {'value': 1470223723000.0,
#                   'value_as_string': '2016-08-03T11:28:43.000Z'}},
#  {'doc_count': 8,
#   'first': {'hits': {'hits': [{'_id': '762978cb2cf4bdabbf51680f7e7add01f81c181a',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-05-11T16:30:42',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '996a6bc8606b343f9dee1111a767bf7e0da0b1d0',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1336753842000]}],
#                      'max_score': None,
#                      'total': 8}},
#   'key': '996a6bc8606b343f9dee1111a767bf7e0da0b1d0',
#   'last_commit': {'value': 1337103936000.0,
#                   'value_as_string': '2012-05-15T17:45:36.000Z'}},
#  {'doc_count': 7,
#   'first': {'hits': {'hits': [{'_id': '89e3acd01e09ee9895c86c5567efea92f2afde3d',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-09-21T12:01:50',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '0c0660cc3c4aa581bf8349cdff17b99d24bfd4bb',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1505995310000]}],
#                      'max_score': None,
#                      'total': 7}},
#   'key': '0c0660cc3c4aa581bf8349cdff17b99d24bfd4bb',
#   'last_commit': {'value': 1514292470000.0,
#                   'value_as_string': '2017-12-26T12:47:50.000Z'}},
#  {'doc_count': 7,
#   'first': {'hits': {'hits': [{'_id': '195a63203d0f88127b55acca66be72e965bed123',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-02-01T17:10:50',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '207d755842ca3b8465fbe88f07e85b85b3d61b1f',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1485969050000]}],
#                      'max_score': None,
#                      'total': 7}},
#   'key': '207d755842ca3b8465fbe88f07e85b85b3d61b1f',
#   'last_commit': {'value': 1495625459000.0,
#                   'value_as_string': '2017-05-24T11:30:59.000Z'}},
#  {'doc_count': 6,
#   'first': {'hits': {'hits': [{'_id': '6a03e4e1f62f3a65f3b87e2cb4bdba13926e9183',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-05-03T12:06:32',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '011256fecd925ec8e1577ca0247ed7eea1052d68',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1336046792000]}],
#                      'max_score': None,
#                      'total': 6}},
#   'key': '011256fecd925ec8e1577ca0247ed7eea1052d68',
#   'last_commit': {'value': 1337052336000.0,
#                   'value_as_string': '2012-05-15T03:25:36.000Z'}},
#  {'doc_count': 6,
#   'first': {'hits': {'hits': [{'_id': '4bcd3699bc7e600662d84caf6eb69c35dbf8a924',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2015-07-17T15:36:28',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '5bc67b84780b40ae898c4ca94f39162bcb52dd5e',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1437147388000]}],
#                      'max_score': None,
#                      'total': 6}},
#   'key': '5bc67b84780b40ae898c4ca94f39162bcb52dd5e',
#   'last_commit': {'value': 1438170511000.0,
#                   'value_as_string': '2015-07-29T11:48:31.000Z'}},
#  {'doc_count': 5,
#   'first': {'hits': {'hits': [{'_id': '386e91ca4d466071b97205de3452fc6d14356151',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2015-11-25T06:23:31',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': 'c72bc7d7a47dd4b218517b2328119ef1cfc732d9',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1448432611000]}],
#                      'max_score': None,
#                      'total': 5}},
#   'key': 'c72bc7d7a47dd4b218517b2328119ef1cfc732d9',
#   'last_commit': {'value': 1450059434000.0,
#                   'value_as_string': '2015-12-14T02:17:14.000Z'}},
#  {'doc_count': 4,
#   'first': {'hits': {'hits': [{'_id': '58cbc69b2e12a0b522a99d49b197d3d276095bb6',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2013-09-13T05:48:50',
#                                            'author_org_name': 'Bitergia',
#                                            'author_uuid': '25d65bccdd9fb01ba8e6d1190eb2b53bb00e37cd',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1379051330000]}],
#                      'max_score': None,
#                      'total': 4}},
#   'key': '25d65bccdd9fb01ba8e6d1190eb2b53bb00e37cd',
#   'last_commit': {'value': 1509190157000.0,
#                   'value_as_string': '2017-10-28T11:29:17.000Z'}},
#  {'doc_count': 4,
#   'first': {'hits': {'hits': [{'_id': 'd0825f29f07e9a0277b3e62787c8ed0800e2b39a',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-05-25T17:43:10',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': 'a58eedcb5150c99b9bb8685607849f3cfc945c31',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1337967790000]}],
#                      'max_score': None,
#                      'total': 4}},
#   'key': 'a58eedcb5150c99b9bb8685607849f3cfc945c31',
#   'last_commit': {'value': 1338907777000.0,
#                   'value_as_string': '2012-06-05T14:49:37.000Z'}},
#  {'doc_count': 3,
#   'first': {'hits': {'hits': [{'_id': '33a9f6b2fa4a910082d8308795be1dedf47957e0',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2010-06-08T16:27:41',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '17d9dbbc7088040166c266865f263ccb8dee4714',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1276014461000]}],
#                      'max_score': None,
#                      'total': 3}},
#   'key': '17d9dbbc7088040166c266865f263ccb8dee4714',
#   'last_commit': {'value': 1276078094000.0,
#                   'value_as_string': '2010-06-09T10:08:14.000Z'}},
#  {'doc_count': 3,
#   'first': {'hits': {'hits': [{'_id': '21459f007de32340bdd1a15a3e3244d3123461bb',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2009-11-23T18:12:21',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '38e94e30c48a5031bfc45812f7c09d8d3e003ea5',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1258999941000]}],
#                      'max_score': None,
#                      'total': 3}},
#   'key': '38e94e30c48a5031bfc45812f7c09d8d3e003ea5',
#   'last_commit': {'value': 1259002547000.0,
#                   'value_as_string': '2009-11-23T18:55:47.000Z'}},
# ...
#                                '_score': None,
#                                '_source': {'author_date': '2016-03-28T11:08:04',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': 'e0e6032e78e3b81857838f35a5aeefdbcabbb114',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1459163284000]}],
#                      'max_score': None,
#                      'total': 2}},
#   'key': 'e0e6032e78e3b81857838f35a5aeefdbcabbb114',
#   'last_commit': {'value': 1459175835000.0,
#                   'value_as_string': '2016-03-28T14:37:15.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '3c697edc2b1bee905854e636327d6a0b23623248',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-04-03T22:45:24',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '05f04576638790d55b20d451b7cd10c0ee257731',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1491259524000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '05f04576638790d55b20d451b7cd10c0ee257731',
#   'last_commit': {'value': 1491259524000.0,
#                   'value_as_string': '2017-04-03T22:45:24.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': 'dceb9744d84803b8a38a03715f8ddd2582c55596',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-08-04T12:03:03',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '077ecab008c9bcedb62d88f228f006f0be74155d',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1501848183000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '077ecab008c9bcedb62d88f228f006f0be74155d',
#   'last_commit': {'value': 1501848183000.0,
#                   'value_as_string': '2017-08-04T12:03:03.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': 'b43a4db70f46939457473d120cd93a8227470ed1',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-10-03T08:58:14',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '12ece20936dd5c1625548c0bc543da6314785e51',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1507021094000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '12ece20936dd5c1625548c0bc543da6314785e51',
#   'last_commit': {'value': 1507021094000.0,
#                   'value_as_string': '2017-10-03T08:58:14.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '4c1b36091514661de947f490fd9bcfaf3fe416cb',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2015-08-08T11:02:17',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '4395f5cabc4c2b2b74d2ea176c8089a1f55ce2ef',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1439031737000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '4395f5cabc4c2b2b74d2ea176c8089a1f55ce2ef',
#   'last_commit': {'value': 1439031737000.0,
#                   'value_as_string': '2015-08-08T11:02:17.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '4e295cabdc08eac5eeb464af21e42d4f9f16984e',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-03-23T14:03:00',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '4595d634885bbc998fd5ebdabb7820a6b8b38fc5',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1490277780000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '4595d634885bbc998fd5ebdabb7820a6b8b38fc5',
#   'last_commit': {'value': 1490277780000.0,
#                   'value_as_string': '2017-03-23T14:03:00.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '86077a356400a4235efec831b61256879ff06d20',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2015-12-08T22:53:10',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '5b2a3b6e76d4dd83bfca2971300ac41a5e4fb769',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1449615190000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '5b2a3b6e76d4dd83bfca2971300ac41a5e4fb769',
#   'last_commit': {'value': 1449615190000.0,
#                   'value_as_string': '2015-12-08T22:53:10.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '1742d21daf7dedad469931a49fbe8a880d4cb7f0',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2016-02-27T21:05:25',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '673c732a138f507fe83738237460555707183d69',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1456607125000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '673c732a138f507fe83738237460555707183d69',
#   'last_commit': {'value': 1456607125000.0,
#                   'value_as_string': '2016-02-27T21:05:25.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '89a01914eee06d3fcc53ad4535160d688d698919',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-04-10T16:46:28',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '6ca63954e4ee2df6be35b39384720e4d4c0908d6',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1491842788000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '6ca63954e4ee2df6be35b39384720e4d4c0908d6',
#   'last_commit': {'value': 1491842788000.0,
#                   'value_as_string': '2017-04-10T16:46:28.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '3777272917eef357e3349e49caba31ff82766593',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-10-17T22:46:36',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '74a144a3e005ade6e772355921710f206fd0e3b1',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1508280396000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '74a144a3e005ade6e772355921710f206fd0e3b1',
#   'last_commit': {'value': 1508280396000.0,
#                   'value_as_string': '2017-10-17T22:46:36.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '2bd9c62400808b1eb6ef1ae3b6d40cbde0005405',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2015-12-04T04:34:00',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '90eeaa86db3a94c03747fb31fef7052168e53334',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1449203640000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '90eeaa86db3a94c03747fb31fef7052168e53334',
#   'last_commit': {'value': 1449203640000.0,
#                   'value_as_string': '2015-12-04T04:34:00.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '6ec0eccc2dd0bdf491a5e9133c18956c684d79d0',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2012-08-09T21:37:57',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '9555dfd67ed0b00b3101ed5d7a2acb235301291e',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1344548277000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '9555dfd67ed0b00b3101ed5d7a2acb235301291e',
#   'last_commit': {'value': 1344548277000.0,
#                   'value_as_string': '2012-08-09T21:37:57.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '1d8d3b3945f6b520b00b8bcc8b322c4a53af2c77',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-01-09T16:52:56',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': '9b233a0d9bac16fcd3845fbc814ef46678280e18',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1483980776000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': '9b233a0d9bac16fcd3845fbc814ef46678280e18',
#   'last_commit': {'value': 1483980776000.0,
#                   'value_as_string': '2017-01-09T16:52:56.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '323ac0661ac59c82180c41e83b6419ec779062e8',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2015-01-14T21:12:14',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': 'a1fa07576fa626e80bd8b3276416388fbe9dd47c',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1421269934000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': 'a1fa07576fa626e80bd8b3276416388fbe9dd47c',
#   'last_commit': {'value': 1421269934000.0,
#                   'value_as_string': '2015-01-14T21:12:14.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': 'f18e262d7b51505128db00490d96ca4a8015facf',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2014-12-05T03:45:47',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': 'c4e7814a60440eb91ad21a396d8d8f64dc040521',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1417751147000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': 'c4e7814a60440eb91ad21a396d8d8f64dc040521',
#   'last_commit': {'value': 1417751147000.0,
#                   'value_as_string': '2014-12-05T03:45:47.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '244ecc43c4b8d1e55ee10e0c9e4052137a8a40c6',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-06-29T12:45:26',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': 'c6e8d9e2b5c7cc2f174df3d20487a6a5a08824ae',
#                                            'project': 'Bitergia'},
#                                '_type': 'items',
#                                'sort': [1498740326000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': 'c6e8d9e2b5c7cc2f174df3d20487a6a5a08824ae',
#   'last_commit': {'value': 1498740326000.0,
#                   'value_as_string': '2017-06-29T12:45:26.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '353ffa149cabe7eb0fe33ee2457c20d71fde9ae2',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-06-07T11:12:08',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': 'c7dd3e3fc036268ed07d5a570655ba02ad4f2035',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1496833928000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': 'c7dd3e3fc036268ed07d5a570655ba02ad4f2035',
#   'last_commit': {'value': 1496833928000.0,
#                   'value_as_string': '2017-06-07T11:12:08.000Z'}},
#  {'doc_count': 1,
#   'first': {'hits': {'hits': [{'_id': '2681b291e60407183b330c8d4826b5721dfa77a6',
#                                '_index': 'git_bitergia_171229_enriched_171229',
#                                '_score': None,
#                                '_source': {'author_date': '2017-12-07T18:54:53',
#                                            'author_org_name': 'Unknown',
#                                            'author_uuid': 'd3ec9b39d81b178650488056026b3bfaad520294',
#                                            'project': 'Grimoirelab'},
#                                '_type': 'items',
#                                'sort': [1512672893000]}],
#                      'max_score': None,
#                      'total': 1}},
#   'key': 'd3ec9b39d81b178650488056026b3bfaad520294',
#   'last_commit': {'value': 1512672893000.0,
#                   'value_as_string': '2017-12-07T18:54:53.000Z'}}]

# %% [markdown]
# ## Create Pandas dataframe
# In order to work with data, we create a Pandas dataframe where each row will contain:
# * Author UUID
# * First commit date
# * Last commit date
# * Author org name
# * Project

# %%
import pandas as pd
from datetime import datetime

# Get a dataframe with each author and their first commit
buckets = []
for bucket_author in result_buckets:
    author = bucket_author['key']

    first = bucket_author['first']['hits']['hits'][0]
    first_commit = first['sort'][0]/1000
    last_commit = bucket_author['last_commit']['value']/1000
    org_name = first['_source']['author_org_name']
    project = first['_source']['project']
    
    buckets.append({
            'first_commit': datetime.utcfromtimestamp(first_commit),
            'last_commit': datetime.utcfromtimestamp(last_commit),
            'author': author,
            'org': org_name,
            'project': project
    })
    
authors_df = pd.DataFrame.from_records(buckets)
authors_df.sort_values(by='first_commit', ascending=False,
                        inplace=True)

pprint(authors_df)
# Out:
#                                       author        first_commit  \
# 82  d3ec9b39d81b178650488056026b3bfaad520294 2017-12-07 18:54:53
# 74  74a144a3e005ade6e772355921710f206fd0e3b1 2017-10-17 22:46:36
# 61  3e07ffee1f3dc6eac7be34d46b0423ab81e2eac7 2017-10-10 16:27:29
# 68  12ece20936dd5c1625548c0bc543da6314785e51 2017-10-03 08:58:14
# 44  0c0660cc3c4aa581bf8349cdff17b99d24bfd4bb 2017-09-21 12:01:50
# 18  3af32d529fce2e7dc632bb26fea5ed4abcb3fcd6 2017-09-07 14:46:30
# 62  60f91e9419cbadd93686b6db9fdde3ba797c7eeb 2017-09-01 13:05:18
# 67  077ecab008c9bcedb62d88f228f006f0be74155d 2017-08-04 12:03:03
# 80  c6e8d9e2b5c7cc2f174df3d20487a6a5a08824ae 2017-06-29 12:45:26
# 81  c7dd3e3fc036268ed07d5a570655ba02ad4f2035 2017-06-07 11:12:08
# 73  6ca63954e4ee2df6be35b39384720e4d4c0908d6 2017-04-10 16:46:28
# 58  00d388d70234b2e2260b874ba121498a23b5b968 2017-04-07 14:47:12
# 66  05f04576638790d55b20d451b7cd10c0ee257731 2017-04-03 22:45:24
# 56  9cc2fc42cd9337dccb3a6f6b305649d9fa13881a 2017-03-29 12:36:51
# 70  4595d634885bbc998fd5ebdabb7820a6b8b38fc5 2017-03-23 14:03:00
# 45  207d755842ca3b8465fbe88f07e85b85b3d61b1f 2017-02-01 17:10:50
# 77  9b233a0d9bac16fcd3845fbc814ef46678280e18 2017-01-09 16:52:56
# 16  71865329622c972b856abae58ad4095cd2086fa2 2016-11-17 16:59:44
# 34  08eab6ef3ea49e880bba3a1a7ae8030c2d0b1297 2016-07-28 16:12:03
# 42  4fcec5a968246d8342e4acfceb9174531c8545c1 2016-07-07 11:53:40
# 65  e0e6032e78e3b81857838f35a5aeefdbcabbb114 2016-03-28 11:08:04
# 72  673c732a138f507fe83738237460555707183d69 2016-02-27 21:05:25
# 20  cc1000a28d57ed5351bb8a62dfff5e37569b2df8 2016-01-20 19:04:30
# 59  104c7a17224abbb218ff602d617c86d237ddfa13 2015-12-17 03:54:15
# 71  5b2a3b6e76d4dd83bfca2971300ac41a5e4fb769 2015-12-08 22:53:10
# 75  90eeaa86db3a94c03747fb31fef7052168e53334 2015-12-04 04:34:00
# 48  c72bc7d7a47dd4b218517b2328119ef1cfc732d9 2015-11-25 06:23:31
# 29  059dcccf4a3c177ff6e496bccaf4da6160732ced 2015-10-11 19:08:22
# 60  2f98dd3b903f804e6a0fd2b044c41fb38d51afeb 2015-09-03 16:35:58
# 69  4395f5cabc4c2b2b74d2ea176c8089a1f55ce2ef 2015-08-08 11:02:17
# ..                                       ...                 ...
# 50  a58eedcb5150c99b9bb8685607849f3cfc945c31 2012-05-25 17:43:10
# 21  16cd95315b0b28ee70e1f73447a64d5e2b964eb5 2012-05-24 12:10:26
# 0   57de6040b8a98143a5eb938109e4b0a907038d77 2012-05-19 07:41:30
# 43  996a6bc8606b343f9dee1111a767bf7e0da0b1d0 2012-05-11 16:30:42
# 46  011256fecd925ec8e1577ca0247ed7eea1052d68 2012-05-03 12:06:32
# 54  519a2fbe7554ca54b193adc1a54c5a2e908a8cba 2012-03-26 15:33:06
# 64  bddd01dce348df74f30fb032ed2bd5558689ed4d 2012-03-23 21:30:02
# 22  27d96590fb2ca5dedd4507bda1d792f295223274 2012-03-12 12:50:31
# 36  05a59bcab4ea18cde6a069bc27d06657254bcb4f 2012-02-10 22:41:29
# 17  637fa327b9edbc6181dc4ce79618e97e796df511 2012-01-28 00:48:28
# 57  b4634e8a22d0f59783a82da335752c04f570483f 2011-05-03 20:38:30
# 35  8034601bb611d8467e91bac7ce56c332790729bd 2011-04-27 16:34:14
# 13  0d1a97da22adbd366a57c174e3106ebdef981ee3 2011-04-26 08:45:01
# 63  97aef671e8098cd92a3dae1ee881eca7958416b1 2011-03-16 17:10:28
# 37  61eeffb994404fb5dd5e20445eb33d731b3e1d29 2011-02-11 19:17:18
# 24  b83582fafb021a9b640b2dfb0404abced7b39661 2011-01-25 15:47:03
# 11  a18a6a31965a46c24113018b752a49eae74fee13 2011-01-21 19:43:44
# 12  3f7832ea49c7e3174f907ec58200ad3c765b7b71 2010-09-10 22:26:41
# 51  17d9dbbc7088040166c266865f263ccb8dee4714 2010-06-08 16:27:41
# 30  35a9d29ad910a5d75c660299a477da7d61497af3 2010-04-10 10:48:32
# 26  8335333ea8bc65ddcffb768919a02b80eff3e640 2010-04-05 15:17:46
# 6   d3fb2dae1d7dc11c8f5a8ddaf019f36e650e044b 2010-02-01 17:17:52
# 41  2be2aadaf1dd3ca7a6a4409846bc0fa33a57a124 2010-01-25 14:08:26
# 39  44725024cabcedb8ec90741eb99661613bfba2e9 2010-01-15 11:17:05
# 52  38e94e30c48a5031bfc45812f7c09d8d3e003ea5 2009-11-23 18:12:21
# 38  1824e55b84e35e19d8cdd414932a54123863cc85 2009-11-11 14:36:42
# 5   858fcf6c665e844966734fcfd9da28b1bddf895a 2009-11-05 15:37:23
# 8   54f3d0fa3116f1b3a3019bdccf563bdbdbfab2c6 2009-11-05 10:50:13
# 23  0a7e39e91aa13ce4b9bfba8717308339e16377d9 2009-11-05 10:48:13
# 15  311d49a75694e820005b26286ee39d6afc8c1b70 2009-10-14 15:23:08
#
#            last_commit            org      project
# 82 2017-12-07 18:54:53        Unknown  Grimoirelab
# 74 2017-10-17 22:46:36        Unknown  Grimoirelab
# 61 2017-10-18 07:22:04        Unknown  Grimoirelab
# 68 2017-10-03 08:58:14        Unknown  Grimoirelab
# 44 2017-12-26 12:47:50       Bitergia     Bitergia
# 18 2017-12-15 11:56:57       Bitergia  Grimoirelab
# 62 2017-09-03 23:51:42        Unknown     Bitergia
# 67 2017-08-04 12:03:03        Unknown  Grimoirelab
# 80 2017-06-29 12:45:26        Unknown     Bitergia
# 81 2017-06-07 11:12:08        Unknown  Grimoirelab
# 73 2017-04-10 16:46:28        Unknown     Bitergia
# 58 2017-08-26 02:09:23        Unknown     Bitergia
# 66 2017-04-03 22:45:24        Unknown     Bitergia
# 56 2017-12-26 12:22:14       Bitergia  Grimoirelab
# 70 2017-03-23 14:03:00        Unknown     Bitergia
# 45 2017-05-24 11:30:59       Bitergia     Bitergia
# 77 2017-01-09 16:52:56        Unknown  Grimoirelab
# 16 2017-12-22 16:44:09       Bitergia  Grimoirelab
# 34 2017-11-06 18:28:46       Bitergia  Grimoirelab
# 42 2016-08-03 11:28:43        Unknown  Grimoirelab
# 65 2016-03-28 14:37:15        Unknown  Grimoirelab
# 72 2016-02-27 21:05:25        Unknown  Grimoirelab
# 20 2017-12-01 19:01:23       Bitergia  Grimoirelab
# 59 2015-12-17 08:25:36        Unknown     Bitergia
# 71 2015-12-08 22:53:10        Unknown     Bitergia
# 75 2015-12-04 04:34:00        Unknown     Bitergia
# 48 2015-12-14 02:17:14        Unknown     Bitergia
# 29 2016-01-05 20:44:26        Unknown  Grimoirelab
# 60 2015-09-03 16:41:38        Unknown     Bitergia
# 69 2015-08-08 11:02:17        Unknown     Bitergia
# ..                 ...            ...          ...
# 50 2012-06-05 14:49:37        Unknown     Bitergia
# 21 2012-09-25 17:41:41        Unknown     Bitergia
# 0  2017-12-28 15:44:22       Bitergia     Bitergia
# 43 2012-05-15 17:45:36        Unknown     Bitergia
# 46 2012-05-15 03:25:36        Unknown     Bitergia
# 54 2012-03-26 15:45:07        Unknown     Bitergia
# 64 2012-03-23 21:31:07        Unknown     Bitergia
# 22 2012-06-22 12:33:08        Unknown     Bitergia
# 36 2012-07-09 16:22:34        Unknown     Bitergia
# 17 2012-10-03 19:01:27  Geeknet, Inc.     Bitergia
# 57 2011-05-03 20:41:59        Unknown     Bitergia
# 35 2011-10-22 16:39:23  Geeknet, Inc.     Bitergia
# 13 2012-08-17 18:30:28  Geeknet, Inc.     Bitergia
# 63 2011-03-16 17:16:09        Unknown     Bitergia
# 37 2012-08-23 14:24:53  Geeknet, Inc.     Bitergia
# 24 2012-01-25 14:00:24  Geeknet, Inc.     Bitergia
# 11 2012-10-03 20:36:51  Geeknet, Inc.     Bitergia
# 12 2011-04-08 14:49:47  Geeknet, Inc.     Bitergia
# 51 2010-06-09 10:08:14        Unknown     Bitergia
# 30 2010-04-28 19:53:15  Geeknet, Inc.     Bitergia
# 26 2010-06-02 16:21:47  Geeknet, Inc.     Bitergia
# 6  2012-08-17 18:39:15  Geeknet, Inc.     Bitergia
# 41 2010-02-22 11:33:15  Geeknet, Inc.     Bitergia
# 39 2010-05-13 15:25:19  Geeknet, Inc.     Bitergia
# 52 2009-11-23 18:55:47        Unknown     Bitergia
# 38 2011-06-30 12:26:46        Unknown     Bitergia
# 5  2012-08-01 16:58:46  Geeknet, Inc.     Bitergia
# 8  2011-06-28 15:28:11  Geeknet, Inc.     Bitergia
# 23 2010-10-11 17:17:11  Geeknet, Inc.     Bitergia
# 15 2010-06-22 14:47:07  Geeknet, Inc.     Bitergia
#
# [83 rows x 5 columns]

# %% [markdown]
# ## Newcomers per year
# Next we will use pandas to group data and count the number of newcomers per year and organization.

# %%
# Group by year of first commit and project, counting number of authors
first_df = authors_df.groupby([authors_df.first_commit.dt.year, authors_df.org])\
                        .agg({'author': pd.Series.nunique})
first_df = first_df.reset_index()
first_df.rename(columns={"first_commit": "year", "author": "newcomers"}, inplace=True)
first_df = first_df.sort_values(by=['year', 'newcomers'], ascending=[False, False])

# %%
# Get top 20 projects based on newcomers from 2008
newcomers_df = pd.DataFrame()
for year in first_df['year'].unique():
    if year > 2008:
        year_df = first_df.loc[first_df['year'] == year].head(20)
        newcomers_df = pd.concat([newcomers_df, year_df])
        
pprint(newcomers_df)
# Out:
#     year                          org  newcomers
# 20  2017                      Unknown         13
# 19  2017                     Bitergia          4
# 17  2016                     Bitergia          3
# 18  2016                      Unknown          3
# 16  2015                      Unknown         10
# 15  2015                     Bitergia          1
# 14  2014                      Unknown          4
# 11  2014                     Bitergia          2
# 12  2014           Eclipse Foundation          1
# 13  2014  Universidad Rey Juan Carlos          1
# 9   2013                     Bitergia          5
# 10  2013         Wikimedia Foundation          1
# 8   2012                      Unknown         12
# 6   2012                     Bitergia          2
# 7   2012                Geeknet, Inc.          1
# 4   2011                Geeknet, Inc.          5
# 5   2011                      Unknown          2
# 2   2010                Geeknet, Inc.          6
# 3   2010                      Unknown          1
# 0   2009                Geeknet, Inc.          4
# 1   2009                      Unknown          2

# %% [markdown]
# ## People Leaving

# %%
# Group by year of last commit and project, counting number of authors
last_df = authors_df.groupby([authors_df.last_commit.dt.year, authors_df.org])\
                        .agg({'author': pd.Series.nunique})
last_df = last_df.reset_index()
last_df.rename(columns={"last_commit": "year", "author": "leaving"}, inplace=True)
last_df = last_df.sort_values(by=['year', 'leaving'], ascending=[False, False])

# %%
# Get top 20 projects based on newcomers from 2008
leaving_df = pd.DataFrame()
for year in last_df['year'].unique():
    if year > 2008:
        year_df = last_df.loc[last_df['year'] == year].head(20)
        leaving_df = pd.concat([leaving_df, year_df])
        
pprint(leaving_df)
# Out:
#     year                          org  leaving
# 14  2017                     Bitergia       15
# 16  2017                      Unknown       15
# 15  2017  Universidad Rey Juan Carlos        1
# 13  2016                      Unknown        5
# 12  2016                     Bitergia        1
# 10  2015                      Unknown        9
# 11  2015         Wikimedia Foundation        1
# 8   2014           Eclipse Foundation        1
# 9   2014                      Unknown        1
# 7   2013                     Bitergia        1
# 6   2012                      Unknown       12
# 5   2012                Geeknet, Inc.        7
# 3   2011                Geeknet, Inc.        3
# 4   2011                      Unknown        3
# 1   2010                Geeknet, Inc.        6
# 2   2010                      Unknown        1
# 0   2009                      Unknown        1

# %% [markdown]
# ## Merge both dataframes
#
# Now we put everything together to keep track of people joining and leaving the community through years.

# %%
final_df = newcomers_df.merge(leaving_df, on=['year','org'], how='outer')
final_df = final_df.fillna(0)
final_df = final_df.sort_values(by=['year', 'org'], ascending=[False, False])

pprint(final_df)
# Out:
#     year                          org  newcomers  leaving
# 0   2017                      Unknown       13.0     15.0
# 21  2017  Universidad Rey Juan Carlos        0.0      1.0
# 1   2017                     Bitergia        4.0     15.0
# 3   2016                      Unknown        3.0      5.0
# 2   2016                     Bitergia        3.0      1.0
# 22  2015         Wikimedia Foundation        0.0      1.0
# 4   2015                      Unknown       10.0      9.0
# 5   2015                     Bitergia        1.0      0.0
# 6   2014                      Unknown        4.0      1.0
# 9   2014  Universidad Rey Juan Carlos        1.0      0.0
# 8   2014           Eclipse Foundation        1.0      1.0
# 7   2014                     Bitergia        2.0      0.0
# 11  2013         Wikimedia Foundation        1.0      0.0
# 10  2013                     Bitergia        5.0      1.0
# 12  2012                      Unknown       12.0     12.0
# 14  2012                Geeknet, Inc.        1.0      7.0
# 13  2012                     Bitergia        2.0      0.0
# 16  2011                      Unknown        2.0      3.0
# 15  2011                Geeknet, Inc.        5.0      3.0
# 18  2010                      Unknown        1.0      1.0
# 17  2010                Geeknet, Inc.        6.0      6.0
# 20  2009                      Unknown        2.0      1.0
# 19  2009                Geeknet, Inc.        4.0      0.0
